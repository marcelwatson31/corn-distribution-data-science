# %%
import seaborn as sb

# %%
import os

# %%
import numpy as np

# %%
import pandas as pd
raw_data = pd.read_csv("C:/Users\kazaz\Desktop\corn\corn3.csv")
print(raw_data)
# Out:
#     Corn Number  Height cm  Mass g  # of Leaves Able to Reproduce
# 0             1         52     100            2                 y
# 1             2         34     150            3                 y
# 2             3         23      12            4                 y
# 3             4         57      70            5                 y
# 4             5         32      32            3                 n
# 5             6         34      12            2                 n
# 6             7         12      35            1                 n
# 7             8         37      67            3                 y
# 8             9         65      89            5                 y
# 9            10         45     150            6                 y
# 10           11         39     129            3                 y
# 11           12         43     111            2                 y
# 12           13         36     111            1                 y
# ...

# %%
data.head()
# Out:
#    Corn Number  Height cm  Mass g  # of Leaves Able to Reproduce
# 0            1         52     100            2                 y
# 1            2         34     150            3                 y
# 2            3         23      12            4                 y
# 3            4         57      70            5                 y
# 4            5         32      32            3                 n

# %%
import seaborn as sns
print(raw_data.shape)
#ax = sns.lineplot(x ='Mass g', y= 'Height cm', data = raw_data)
ax = sns.lineplot(x ='Corn Number', y= 'Height cm', data = raw_data, hue = 'Mass g')
# Out:
# (20, 5)

# %%
ax = sns.lineplot(x ='Corn Number', y= 'Height cm', data = raw_data, hue = 'Mass g', style='Mass g')

# %%
sns.set(rc={'figure.figsize':(15,15)})
ax = sns.lineplot(x ='Corn Number', y= 'Height cm', data = raw_data, markers= True,hue ='Able to Reproduce')
ax = sns.relplot(x ='Corn Number', y= 'Height cm', data = raw_data, markers= True, hue ='Able to Reproduce')
ax = sns.relplot(x ='Corn Number', y= 'Height cm', data = raw_data, markers= True,hue ='Able to Reproduce', style = '# of Leaves')
ax = sns.relplot(x ='Corn Number', y= 'Height cm', data = raw_data, markers= True,hue ='Able to Reproduce', style = '# of Leaves', size ='# of Leaves')
ax = sns.displot(x ='# of Leaves', data = raw_data, hue ='Able to Reproduce', kind="kde", fill=True)
ax = sns.displot(x ='# of Leaves', data = raw_data, hue ='Able to Reproduce', kind="kde")
sns.displot(raw_data, x="Mass g", y="Height cm", kind="kde")
sns.displot(raw_data, x="Corn Number", y="Height cm", hue='# of Leaves')
ax = sns.displot(x ='Mass g', data = raw_data, hue ='Able to Reproduce')
sns.lmplot(x ='Corn Number', y= 'Height cm', data = raw_data, markers= True,)
sns.lmplot(x ='# of Leaves', y= 'Height cm', data = raw_data, markers= True)
sns.jointplot(data =raw_data, x="Mass g", y="Height cm", hue="# of Leaves")
sns.jointplot(data =raw_data, x="Mass g", y="Height cm", hue="Corn Number")
sns.jointplot(data =raw_data, x="Mass g", y="Height cm", hue="Corn Number", kind = "hist")
# Out:
# c:\users\kazaz\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\kazaz\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\kazaz\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\kazaz\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\users\kazaz\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...
